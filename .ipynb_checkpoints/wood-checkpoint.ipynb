# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # 2. Load the Data

# %%
data = pd.read_excel("Infrastructure.xlsx")

# %% [markdown]
# # 3. Data Information and Initial Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Inund Depth obs. (m)                    20874 non-null  float64
#  1   Damage Indices (0-4)                    20874 non-null  int64
#  2   Material (RC, Steel, Wood, Masonry)     20874 non-null  object
#  3   Structure (Building or Infrastructure)  20874 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 652.4+ KB

# %%
data.drop(columns=["Structure (Building or Infrastructure)"], inplace=True)

# %%
data.head()
# Out:
#    Inund Depth obs. (m)  Damage Indices (0-4)  \
# 0                   2.1                     2
# 1                   1.8                     2
# 2                   2.2                     2
# 3                   2.0                     2
# 4                   2.0                     2
#
#   Material (RC, Steel, Wood, Masonry)
# 0                             Masonry
# 1                             Masonry
# 2                             Masonry
# 3                                Wood
# 4                                Wood

# %% [markdown]
# #  4.Renaming Columns for Clarity

# %%
data.rename(columns={
    'Inund Depth obs. (m)': 'Inund Depth',
    'Damage Indices (0-4)': 'Damage Indices',
    'Material (RC, Steel, Wood, Masonry)': 'Material'
}, inplace=True)

# Print the DataFrame with renamed columns
data.head()
# Out:
#    Inund Depth  Damage Indices Material
# 0          2.1               2  Masonry
# 1          1.8               2  Masonry
# 2          2.2               2  Masonry
# 3          2.0               2     Wood
# 4          2.0               2     Wood

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     20874 non-null  float64
#  1   Damage Indices  20874 non-null  int64
#  2   Material        20874 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 489.4+ KB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Inund Depth'] = scaler.fit_transform(data[['Inund Depth']])  # Original column overwrite ho gaya

# %%
data = data.loc[data['Material'] == 'Wood']

data.head()
# Out:
#    Inund Depth  Damage Indices Material
# 3     0.123932               2     Wood
# 4     0.123932               2     Wood
# 6     0.085470               2     Wood
# 8     0.123932               2     Wood
# 9     0.128205               2     Wood

# %% [markdown]
# # 5. Value Counts and Filtering the Data

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.076923    474
# 0.081197    464
# 0.072650    428
# 0.089744    409
# 0.068376    407
#            ...
# 0.066239      1
# 0.126068      1
# 0.076068      1
# 0.057692      1
# 0.743590      1
# Name: Inund Depth, Length: 287, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 4    5807
# 2    4965
# 3    3200
# 1    1226
# 0      55
# Name: Damage Indices, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 4    5807
# 2    4965
# 3    3200
# 1    1226
# 0      55
# Name: Damage Indices, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15253 entries, 3 to 20873
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     15253 non-null  float64
#  1   Damage Indices  15253 non-null  int64
#  2   Material        15253 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 476.7+ KB

# %%
data.drop(data[(data['Damage Indices'] == 0)].index, inplace=True)

# %%
data["Damage Indices"].value_counts()
# Out:
# 4    5807
# 2    4965
# 3    3200
# 1    1226
# Name: Damage Indices, dtype: int64

# %%
data.shape
# Out:
# (15198, 3)

# %%
data.duplicated().sum()
# Out:
# 14712

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.076923    472
# 0.081197    463
# 0.072650    428
# 0.089744    409
# 0.068376    407
#            ...
# 0.267949      1
# 0.126068      1
# 0.076068      1
# 0.057692      1
# 0.743590      1
# Name: Inund Depth, Length: 278, dtype: int64

# %% [markdown]
# # 6. One-Hot Encoding for Categorical Variables

# %%
pd.get_dummies(data,columns=["Damage Indices","Material"])
# Out:
#        Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 3         0.123932                 0                 1                 0
# 4         0.123932                 0                 1                 0
# 6         0.085470                 0                 1                 0
# 8         0.123932                 0                 1                 0
# 9         0.128205                 0                 1                 0
# ...            ...               ...               ...               ...
# 20869     0.376068                 0                 0                 0
# 20870     0.376068                 0                 0                 0
# 20871     0.141026                 0                 0                 1
# 20872     0.354701                 0                 0                 0
# 20873     0.397436                 0                 0                 1
#
#        Damage Indices_4  Material_Wood
# 3                     0              1
# 4                     0              1
# 6                     0              1
# 8                     0              1
# 9                     0              1
# ...                 ...            ...
# 20869                 1              1
# 20870                 1              1
# 20871                 0              1
# 20872                 1              1
# 20873                 0              1
#
# [15198 rows x 6 columns]

# %%
data = pd.get_dummies(data,columns=["Damage Indices","Material"],drop_first= False)
data.head()
# Out:
#    Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 3     0.123932                 0                 1                 0
# 4     0.123932                 0                 1                 0
# 6     0.085470                 0                 1                 0
# 8     0.123932                 0                 1                 0
# 9     0.128205                 0                 1                 0
#
#    Damage Indices_4  Material_Wood
# 3                 0              1
# 4                 0              1
# 6                 0              1
# 8                 0              1
# 9                 0              1

# %%
data.shape
# Out:
# (15198, 6)

# %%
data.duplicated().sum()
# Out:
# 14712

# %% [markdown]
# # 7. Define Features and Target Variables

# %%
# Define features (X) and target (y)
X = data[['Inund Depth', 'Material_Wood']]
y = data[['Damage Indices_1','Damage Indices_2', 'Damage Indices_3', 'Damage Indices_4']]

# %%
y = np.argmax(y.values, axis=1)

# %% [markdown]
# # 8. Split the Data into Training, Validation, and Test Sets

# %%
from sklearn.model_selection import train_test_split

# First, split the data into 90% training+validation and 10% testing
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Further split the training+validation set into training (80%) and validation (20%)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=0)

# %% [markdown]
# # 9. Initialize and Train the Random Forest Model

# %%
# Step 4: Initialize and Train the Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# # 10. Evaluate the Model on the Test Set

# %%
# Step 6: Evaluate on the Test Set
y_test_pred = rf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.774671052631579

# %% [markdown]
# # 11. Classification Report

# %%
# Step 7: Detailed Classification Report
print("Classification Report (Test Set):")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.74      0.25      0.37       231
#            1       0.78      0.91      0.84      1007
#            2       0.62      0.66      0.64       650
#            3       0.87      0.82      0.84      1152
#
#     accuracy                           0.77      3040
#    macro avg       0.75      0.66      0.67      3040
# weighted avg       0.78      0.77      0.76      3040

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_test_pred)


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])


plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")


plt.show()
