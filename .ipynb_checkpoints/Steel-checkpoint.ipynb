# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # 2. Load the Data

# %%
data = pd.read_excel("Infrastructure.xlsx")

# %% [markdown]
# # 3. Data Information and Initial Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Inund Depth obs. (m)                    20874 non-null  float64
#  1   Damage Indices (0-4)                    20874 non-null  int64
#  2   Material (RC, Steel, Wood, Masonry)     20874 non-null  object
#  3   Structure (Building or Infrastructure)  20874 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 652.4+ KB

# %%
data.drop(columns=["Structure (Building or Infrastructure)"], inplace=True)

# %%
data.head()
# Out:
#    Inund Depth obs. (m)  Damage Indices (0-4)  \
# 0                   2.1                     2
# 1                   1.8                     2
# 2                   2.2                     2
# 3                   2.0                     2
# 4                   2.0                     2
#
#   Material (RC, Steel, Wood, Masonry)
# 0                             Masonry
# 1                             Masonry
# 2                             Masonry
# 3                                Wood
# 4                                Wood

# %% [markdown]
# #  4.Renaming Columns for Clarity

# %%
data.rename(columns={
    'Inund Depth obs. (m)': 'Inund Depth',
    'Damage Indices (0-4)': 'Damage Indices',
    'Material (RC, Steel, Wood, Masonry)': 'Material'
}, inplace=True)

# Print the DataFrame with renamed columns
data.head()
# Out:
#    Inund Depth  Damage Indices Material
# 0          2.1               2  Masonry
# 1          1.8               2  Masonry
# 2          2.2               2  Masonry
# 3          2.0               2     Wood
# 4          2.0               2     Wood

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     20874 non-null  float64
#  1   Damage Indices  20874 non-null  int64
#  2   Material        20874 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 489.4+ KB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Inund Depth'] = scaler.fit_transform(data[['Inund Depth']])  # Original column overwrite ho gaya

# %%
data = data.loc[data['Material'] == 'Steel']

data.head()
# Out:
#     Inund Depth  Damage Indices Material
# 26     0.119658               2    Steel
# 57     0.170940               3    Steel
# 60     0.115385               2    Steel
# 72     0.196581               3    Steel
# 74     0.102564               2    Steel

# %% [markdown]
# # 5. Value Counts and Filtering the Data

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.188034    69
# 0.183761    65
# 0.085470    61
# 0.196581    55
# 0.081197    53
#             ..
# 0.048291     1
# 0.581197     1
# 0.649573     1
# 0.517094     1
# 0.589744     1
# Name: Inund Depth, Length: 164, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 3    1231
# 2     814
# 4     230
# 1      81
# 0      15
# Name: Damage Indices, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 3    1231
# 2     814
# 4     230
# 1      81
# 0      15
# Name: Damage Indices, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2371 entries, 26 to 20857
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     2371 non-null   float64
#  1   Damage Indices  2371 non-null   int64
#  2   Material        2371 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 74.1+ KB

# %%
data.drop(data[(data['Damage Indices'] == 0)].index, inplace=True)

# %%
data["Damage Indices"].value_counts()
# Out:
# 3    1231
# 2     814
# 4     230
# 1      81
# Name: Damage Indices, dtype: int64

# %%
data.shape
# Out:
# (2356, 3)

# %%
data.duplicated().sum()
# Out:
# 2064

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.188034    69
# 0.183761    65
# 0.085470    61
# 0.196581    55
# 0.145299    53
#             ..
# 0.662393     1
# 0.679487     1
# 0.581197     1
# 0.649573     1
# 0.619658     1
# Name: Inund Depth, Length: 158, dtype: int64

# %% [markdown]
# # 6. One-Hot Encoding for Categorical Variables

# %%
pd.get_dummies(data,columns=["Damage Indices","Material"])
# Out:
#        Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 26        0.119658                 0                 1                 0
# 57        0.170940                 0                 0                 1
# 60        0.115385                 0                 1                 0
# 72        0.196581                 0                 0                 1
# 74        0.102564                 0                 1                 0
# ...            ...               ...               ...               ...
# 20845     0.384615                 0                 0                 1
# 20846     0.380342                 0                 0                 1
# 20850     0.376068                 0                 0                 0
# 20852     0.371795                 0                 0                 1
# 20857     0.175214                 1                 0                 0
#
#        Damage Indices_4  Material_Steel
# 26                    0               1
# 57                    0               1
# 60                    0               1
# 72                    0               1
# 74                    0               1
# ...                 ...             ...
# 20845                 0               1
# 20846                 0               1
# 20850                 1               1
# 20852                 0               1
# 20857                 0               1
#
# [2356 rows x 6 columns]

# %%
data = pd.get_dummies(data,columns=["Damage Indices","Material"],drop_first= False)
data.head()
# Out:
#     Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 26     0.119658                 0                 1                 0
# 57     0.170940                 0                 0                 1
# 60     0.115385                 0                 1                 0
# 72     0.196581                 0                 0                 1
# 74     0.102564                 0                 1                 0
#
#     Damage Indices_4  Material_Steel
# 26                 0               1
# 57                 0               1
# 60                 0               1
# 72                 0               1
# 74                 0               1

# %%
data.shape
# Out:
# (2356, 6)

# %%
data.duplicated().sum()
# Out:
# 2064

# %% [markdown]
# # 7. Define Features and Target Variables

# %%
# Define features (X) and target (y)
X = data[['Inund Depth', 'Material_Steel']]
y = data[['Damage Indices_1','Damage Indices_2', 'Damage Indices_3', 'Damage Indices_4']]

# %%
y = np.argmax(y.values, axis=1)

# %% [markdown]
# # 8. Split the Data into Training, Validation, and Test Sets

# %%
from sklearn.model_selection import train_test_split

# First, split the data into 90% training+validation and 10% testing
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Further split the training+validation set into training (80%) and validation (20%)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=0)

# %% [markdown]
# # 9. Initialize and Train the Random Forest Model

# %%
# Step 4: Initialize and Train the Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# # 10. Evaluate the Model on the Test Set

# %%
# Step 6: Evaluate on the Test Set
y_test_pred = rf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.6970338983050848

# %% [markdown]
# # 11. Classification Report

# %%
# Step 7: Detailed Classification Report
print("Classification Report (Test Set):")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20        18
#            1       0.75      0.72      0.73       158
#            2       0.69      0.85      0.76       240
#            3       0.41      0.16      0.23        56
#
#     accuracy                           0.70       472
#    macro avg       0.71      0.46      0.48       472
# weighted avg       0.69      0.70      0.67       472

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_test_pred)


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])


plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")


plt.show()
