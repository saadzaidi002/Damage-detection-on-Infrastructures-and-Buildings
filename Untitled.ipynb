# %%
import pandas as pd

# %%
data = pd.read_excel("building_ML.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     1908 non-null   float64
#  1   Damage Indices  1908 non-null   int64
#  2   Material        1908 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 44.8+ KB

# %%
data['Material'].unique()
# Out:
# array(['Masonry', 'Wood', 'Steel', 'Reinforced concrete'], dtype=object)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder


# Label Encoding
label_encoder = LabelEncoder()
data['Material_Label'] = label_encoder.fit_transform(data['Material'])

print(data.head())

# %%
data.head()
# Out:
#    Inund Depth  Damage Indices Material  Material_Label
# 0         -0.6               0  Masonry               0
# 1         -0.5               0     Wood               3
# 2         -0.4               0  Masonry               0
# 3         -0.4               0     Wood               3
# 4         -0.3               0  Masonry               0

# %%
data.to_excel("BUILDING.xlsx", index=False)
