# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # 2. Load the Data

# %%
data = pd.read_excel("Infrastructure.xlsx")

# %% [markdown]
# # 3. Data Information and Initial Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Inund Depth obs. (m)                    20874 non-null  float64
#  1   Damage Indices (0-4)                    20874 non-null  int64
#  2   Material (RC, Steel, Wood, Masonry)     20874 non-null  object
#  3   Structure (Building or Infrastructure)  20874 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 652.4+ KB

# %%
data.drop(columns=["Structure (Building or Infrastructure)"], inplace=True)

# %%
data.head()
# Out:
#    Inund Depth obs. (m)  Damage Indices (0-4)  \
# 0                   2.1                     2
# 1                   1.8                     2
# 2                   2.2                     2
# 3                   2.0                     2
# 4                   2.0                     2
#
#   Material (RC, Steel, Wood, Masonry)
# 0                             Masonry
# 1                             Masonry
# 2                             Masonry
# 3                                Wood
# 4                                Wood

# %% [markdown]
# #  4.Renaming Columns for Clarity

# %%
data.rename(columns={
    'Inund Depth obs. (m)': 'Inund Depth',
    'Damage Indices (0-4)': 'Damage Indices',
    'Material (RC, Steel, Wood, Masonry)': 'Material'
}, inplace=True)

# Print the DataFrame with renamed columns
data.head()
# Out:
#    Inund Depth  Damage Indices Material
# 0          2.1               2  Masonry
# 1          1.8               2  Masonry
# 2          2.2               2  Masonry
# 3          2.0               2     Wood
# 4          2.0               2     Wood

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20874 entries, 0 to 20873
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     20874 non-null  float64
#  1   Damage Indices  20874 non-null  int64
#  2   Material        20874 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 489.4+ KB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Inund Depth'] = scaler.fit_transform(data[['Inund Depth']])  # Original column overwrite ho gaya

# %%
data = data.loc[data['Material'] == 'Reinforced concrete']

data.head()
# Out:
#      Inund Depth  Damage Indices             Material
# 15      0.132479               2  Reinforced concrete
# 16      0.132479               2  Reinforced concrete
# 71      0.128205               2  Reinforced concrete
# 95      0.123932               2  Reinforced concrete
# 120     0.111111               2  Reinforced concrete

# %% [markdown]
# # 5. Value Counts and Filtering the Data

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.111111    29
# 0.141026    13
# 0.085470    13
# 0.123932    12
# 0.098291    12
#             ..
# 0.679487     1
# 0.589744     1
# 0.063675     1
# 0.239316     1
# 0.376068     1
# Name: Inund Depth, Length: 130, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 2    223
# 3    194
# 4     84
# 1     17
# 0      1
# Name: Damage Indices, dtype: int64

# %%
data["Damage Indices"].value_counts()
# Out:
# 2    223
# 3    194
# 4     84
# 1     17
# 0      1
# Name: Damage Indices, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 519 entries, 15 to 20842
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Inund Depth     519 non-null    float64
#  1   Damage Indices  519 non-null    int64
#  2   Material        519 non-null    object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 16.2+ KB

# %%
data.drop(data[(data['Damage Indices'] == 0) | (data['Damage Indices'] == 0) ].index, inplace=True)

# %%
data["Damage Indices"].value_counts()
# Out:
# 2    223
# 3    194
# 4     84
# 1     17
# Name: Damage Indices, dtype: int64

# %%
data.shape
# Out:
# (518, 3)

# %%
data.duplicated().sum()
# Out:
# 314

# %%
data['Inund Depth'].value_counts()
# Out:
# 0.111111    29
# 0.141026    13
# 0.085470    13
# 0.123932    12
# 0.098291    12
#             ..
# 0.679487     1
# 0.589744     1
# 0.063675     1
# 0.239316     1
# 0.376068     1
# Name: Inund Depth, Length: 130, dtype: int64

# %% [markdown]
# # 6. One-Hot Encoding for Categorical Variables

# %%
pd.get_dummies(data,columns=["Damage Indices","Material"])
# Out:
#        Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 15        0.132479                 0                 1                 0
# 16        0.132479                 0                 1                 0
# 71        0.128205                 0                 1                 0
# 95        0.123932                 0                 1                 0
# 120       0.111111                 0                 1                 0
# ...            ...               ...               ...               ...
# 20711     0.269231                 0                 0                 0
# 20712     0.188034                 0                 0                 1
# 20722     0.401709                 0                 0                 1
# 20827     0.367521                 0                 0                 1
# 20842     0.376068                 0                 0                 1
#
#        Damage Indices_4  Material_Reinforced concrete
# 15                    0                             1
# 16                    0                             1
# 71                    0                             1
# 95                    0                             1
# 120                   0                             1
# ...                 ...                           ...
# 20711                 1                             1
# 20712                 0                             1
# 20722                 0                             1
# 20827                 0                             1
# 20842                 0                             1
#
# [518 rows x 6 columns]

# %%
data = pd.get_dummies(data,columns=["Damage Indices","Material"],drop_first= False)
data.head()
# Out:
#      Inund Depth  Damage Indices_1  Damage Indices_2  Damage Indices_3  \
# 15      0.132479                 0                 1                 0
# 16      0.132479                 0                 1                 0
# 71      0.128205                 0                 1                 0
# 95      0.123932                 0                 1                 0
# 120     0.111111                 0                 1                 0
#
#      Damage Indices_4  Material_Reinforced concrete
# 15                  0                             1
# 16                  0                             1
# 71                  0                             1
# 95                  0                             1
# 120                 0                             1

# %%
data.shape
# Out:
# (518, 6)

# %%
data.duplicated().sum()
# Out:
# 314

# %% [markdown]
# # 7. Define Features and Target Variables

# %%
# Define features (X) and target (y)
X = data[['Inund Depth', 'Material_Reinforced concrete']]
y = data[['Damage Indices_2', 'Damage Indices_3', 'Damage Indices_4']]

# %%
y = np.argmax(y.values, axis=1)

# %% [markdown]
# # 8. Split the Data into Training, Validation, and Test Sets

# %%
from sklearn.model_selection import train_test_split

# First, split the data into 90% training+validation and 10% testing
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Further split the training+validation set into training (80%) and validation (20%)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=0)

# %% [markdown]
# # 9. Initialize and Train the Random Forest Model

# %%
# Step 4: Initialize and Train the Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# # 10. Evaluate the Model on the Test Set

# %%
# Step 6: Evaluate on the Test Set
y_test_pred = rf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.6346153846153846

# %% [markdown]
# # 11. Classification Report

# %%
# Step 7: Detailed Classification Report
print("Classification Report (Test Set):")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83        51
#            1       0.50      0.49      0.49        35
#            2       0.35      0.39      0.37        18
#
#     accuracy                           0.63       104
#    macro avg       0.56      0.57      0.56       104
# weighted avg       0.64      0.63      0.64       104

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_test_pred)


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])


plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")


plt.show()
