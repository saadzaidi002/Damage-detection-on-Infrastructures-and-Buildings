# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# # 2. Load the Data

# %%
data = pd.read_excel("Building_data.xlsx")

# %% [markdown]
# # 3. Data Information and Initial Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60718 entries, 0 to 60717
# Data columns (total 4 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Inund Depth obs. (m)                    60718 non-null  float64
#  1   Damage Indices (0-4)                    60718 non-null  int64
#  2   Material (RC, Steel, Wood, Masonry)     60718 non-null  object
#  3   Structure (Building or Infrastructure)  60718 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
data.drop(columns=["Structure (Building or Infrastructure)"], inplace=True)

# %%
data.head()
# Out:
#    Inund Depth obs. (m)  Damage Indices (0-4)  \
# 0                  -0.6                     0
# 1                  -0.5                     0
# 2                  -0.5                     0
# 3                  -0.4                     0
# 4                  -0.4                     0
#
#   Material (RC, Steel, Wood, Masonry)
# 0                             Masonry
# 1                                Wood
# 2                                Wood
# 3                             Masonry
# 4                                Wood

# %% [markdown]
# #  4.Renaming Columns for Clarity

# %%
data.rename(columns={
    'Inund Depth obs. (m)': 'Inund Depth',
    'Damage Indices (0-4)': 'Damage Indices',
    'Material (RC, Steel, Wood, Masonry)': 'Material'
}, inplace=True)

# Print the DataFrame with renamed columns
data.head()
# Out:
#    Inund Depth  Damage Indices Material
# 0         -0.6               0  Masonry
# 1         -0.5               0     Wood
# 2         -0.5               0     Wood
# 3         -0.4               0  Masonry
# 4         -0.4               0     Wood

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Inund Depth'] = scaler.fit_transform(data[['Inund Depth']])  # Original column overwrite ho gaya

# %% [markdown]
# # 5. Value Counts and Filtering the Data

# %%
data["Damage Indices"].value_counts()
# Out:
# 2    23636
# 4    16991
# 3    13366
# 1     6386
# 0      339
# Name: Damage Indices, dtype: int64

# %%
data.drop(data[(data['Damage Indices'] == 2) | (data['Damage Indices'] == 3) | (data['Damage Indices'] == 4)].index, inplace=True)

# %%
data["Damage Indices"].value_counts()
# Out:
# 1    6386
# 0     339
# Name: Damage Indices, dtype: int64

# %%
data.shape
# Out:
# (6725, 3)

# %%
data.duplicated().sum()
# Out:
# 6343

# %% [markdown]
# # 6. One-Hot Encoding for Categorical Variables

# %%
pd.get_dummies(data,columns=["Damage Indices","Material"])
# Out:
#        Inund Depth  Damage Indices_0  Damage Indices_1  Material_Masonry  \
# 0         0.000000                 1                 0                 1
# 1         0.004065                 1                 0                 0
# 2         0.004065                 1                 0                 0
# 3         0.008130                 1                 0                 1
# 4         0.008130                 1                 0                 0
# ...            ...               ...               ...               ...
# 46818     0.219512                 0                 1                 0
# 54233     0.341463                 1                 0                 0
# 54330     0.345528                 0                 1                 0
# 55167     0.389024                 0                 1                 0
# 56163     0.451220                 0                 1                 0
#
#        Material_Reinforced concrete  Material_Steel  Material_Wood
# 0                                 0               0              0
# 1                                 0               0              1
# 2                                 0               0              1
# 3                                 0               0              0
# 4                                 0               0              1
# ...                             ...             ...            ...
# 46818                             0               0              1
# 54233                             0               0              1
# 54330                             1               0              0
# 55167                             0               0              1
# 56163                             0               0              1
#
# [6725 rows x 7 columns]

# %%
data = pd.get_dummies(data,columns=["Damage Indices","Material"],drop_first= False)
data.head()
# Out:
#    Inund Depth  Damage Indices_0  Damage Indices_1  Material_Masonry  \
# 0     0.000000                 1                 0                 1
# 1     0.004065                 1                 0                 0
# 2     0.004065                 1                 0                 0
# 3     0.008130                 1                 0                 1
# 4     0.008130                 1                 0                 0
#
#    Material_Reinforced concrete  Material_Steel  Material_Wood
# 0                             0               0              0
# 1                             0               0              1
# 2                             0               0              1
# 3                             0               0              0
# 4                             0               0              1

# %%
data.shape
# Out:
# (6725, 7)

# %% [markdown]
# # 7. Define Features and Target Variables

# %%
# Define features (X) and target (y)
X = data[['Inund Depth', 'Material_Reinforced concrete', 'Material_Steel', 'Material_Wood']]
y = data[['Damage Indices_0','Damage Indices_1']]

# %%
y = np.argmax(y.values, axis=1)

# %% [markdown]
# # 8. Split the Data into Training, Validation, and Test Sets

# %%
from sklearn.model_selection import train_test_split

# First, split the data into 90% training+validation and 10% testing
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Further split the training+validation set into training (80%) and validation (20%)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=0)

# %% [markdown]
# # 9. Initialize and Train the Random Forest Model

# %%
# Step 4: Initialize and Train the Random Forest Model
rf = RandomForestClassifier(n_estimators=100, random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# # 10. Evaluate the Model on the Test Set

# %%
y_test_pred = rf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: 0.9472118959107807

# %% [markdown]
# # 11. Classification Report

# %%
print("Classification Report (Test Set):")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.52      0.15      0.24        72
#            1       0.95      0.99      0.97      1273
#
#     accuracy                           0.95      1345
#    macro avg       0.74      0.57      0.60      1345
# weighted avg       0.93      0.95      0.93      1345

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_test_pred)


plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=[0, 1, 2], yticklabels=[0, 1, 2])


plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")


plt.show()
